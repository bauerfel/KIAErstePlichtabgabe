# %% [markdown]
# # Data Preparation

# %% [markdown]
# This notebook creates adds new data from other files new features (feature-engineering), clean up the data by deleting rows with missing values and
#
# - Aggregate data from external data sources
# - Feature engineering
# - Data cleaning

# %%
# Libraries
import os
import re
import fnmatch
import datetime
import numpy as np
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Aggregate data from external data sources

# %% [markdown]
# The data is originaly form the modul data analytics. The first part is to clean up the data and aggregate the data with other sources.
#
# The main idea originates from data analytics week 3.

# %% [markdown]
# ### Import the data

# %%
# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_zurich_with_bfs.csv', sep=',', encoding='utf-8')

# Get number of rows and columns
df.shape
# Out:
# (870, 8)

# %% [markdown]
# ### Add municipality data

# %%
# Meaning of variables:
# bfs_number: official municipality id
# bfs_name: official municipality name
# pop: number of residents (=population)
# pop_dens: population density (pop per km2)
# frg_pct: percentage foreigners
# emp: numer of employees

df_municip = pd.read_excel('municipality_data.xlsx', 
                           sheet_name='data_for_import')
df_municip.head(5)
# Out:
#    bfs_number            bfs_name    pop     pop_dens    frg_pct     emp
# 0           1     Aeugst am Albis   1981   250.442478  14.184755   442.0
# 1           2  Affoltern am Albis  12303  1161.756374  28.700317  6920.0
# 2           3          Bonstetten   5572   749.932705  16.564968  1014.0
# 3           4     Hausen am Albis   3751   275.808824  16.022394  1021.0
# 4           5            Hedingen   3778   578.560490  16.410799  1478.0

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df = df.merge(df_municip[['bfs_number', 
                            'bfs_name',
                            'pop', 
                            'pop_dens', 
                            'frg_pct', 
                            'emp']], 
                on="bfs_number")
df.head(5)
# Out:
#    bfs_number  rooms  area  price  postalcode               address  \
# 0         112    3.5   122   3180        8633  Sunnenbergstrasse 15
# 1         112    4.0    87   1690        8633   Blumenbergstrasse 7
# 2         112    3.5    92   2350        8608                   NaN
# 3         112    3.5   130   2500        8608                   NaN
# 4         261    2.5    78   3760        8002        Lavaterstr. 63
#
#          town                                    description_raw bfs_name  \
# 0  Wolfhausen  «Grosse Galerie, Terrasse mit Pergola, Berg- u...  Bubikon
# 1  Wolfhausen                     «Sehr grosse 4 Zimmer Wohnung»  Bubikon
# 2     Bubikon             «Eigentumsstandard mit grossem Garten»  Bubikon
# 3     Bubikon                        «CHARMANT HELL UND ZENTRAL»  Bubikon
# 4      Zürich            «Wunderschöne Wohnung im Enge-Quartier»   Zürich
#
#       pop     pop_dens    frg_pct       emp
# 0    7344   632.558140  11.410675    3617.0
# 1    7344   632.558140  11.410675    3617.0
# 2    7344   632.558140  11.410675    3617.0
# 3    7344   632.558140  11.410675    3617.0
# 4  420217  4778.994655  32.458468  491193.0

# %%
df.shape
# Out:
# (870, 13)

# %% [markdown]
# ### Add tax incom per municipal

# %%
df_tax_income = pd.read_csv('steuerbares_einkommen_2017.csv',
                            sep=',', encoding='utf-8', 
                            header=0, names=['bfs_number', 'bfs_name', 'yearly_income_in_mio', 'tax_income'])
df_tax_income.head(5)
# Out:
#    bfs_number            bfs_name yearly_income_in_mio tax_income
# 0           1     Aeugst am Albis                   98    108'788
# 1           2  Affoltern am Albis                  391     72'583
# 2           3          Bonstetten                  224     91'002
# 3           4     Hausen am Albis                  148     91'766
# 4           5            Hedingen                  155     94'456

# %%
df_tax_income['tax_income'] = df_tax_income['tax_income'].str.replace("'", "").astype(int)

# %%
df.head(4)
# Out:
#    bfs_number  rooms  area  price  postalcode               address  \
# 0         112    3.5   122   3180        8633  Sunnenbergstrasse 15
# 1         112    4.0    87   1690        8633   Blumenbergstrasse 7
# 2         112    3.5    92   2350        8608                   NaN
# 3         112    3.5   130   2500        8608                   NaN
#
#          town                                    description_raw bfs_name  \
# 0  Wolfhausen  «Grosse Galerie, Terrasse mit Pergola, Berg- u...  Bubikon
# 1  Wolfhausen                     «Sehr grosse 4 Zimmer Wohnung»  Bubikon
# 2     Bubikon             «Eigentumsstandard mit grossem Garten»  Bubikon
# 3     Bubikon                        «CHARMANT HELL UND ZENTRAL»  Bubikon
#
#     pop   pop_dens    frg_pct     emp
# 0  7344  632.55814  11.410675  3617.0
# 1  7344  632.55814  11.410675  3617.0
# 2  7344  632.55814  11.410675  3617.0
# 3  7344  632.55814  11.410675  3617.0

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df = df.merge(df_tax_income[['bfs_number', 
                            'tax_income']], 
                on="bfs_number")
df.head(5)
# Out:
#    bfs_number  rooms  area  price  postalcode               address  \
# 0         112    3.5   122   3180        8633  Sunnenbergstrasse 15
# 1         112    4.0    87   1690        8633   Blumenbergstrasse 7
# 2         112    3.5    92   2350        8608                   NaN
# 3         112    3.5   130   2500        8608                   NaN
# 4         261    2.5    78   3760        8002        Lavaterstr. 63
#
#          town                                    description_raw bfs_name  \
# 0  Wolfhausen  «Grosse Galerie, Terrasse mit Pergola, Berg- u...  Bubikon
# 1  Wolfhausen                     «Sehr grosse 4 Zimmer Wohnung»  Bubikon
# 2     Bubikon             «Eigentumsstandard mit grossem Garten»  Bubikon
# 3     Bubikon                        «CHARMANT HELL UND ZENTRAL»  Bubikon
# 4      Zürich            «Wunderschöne Wohnung im Enge-Quartier»   Zürich
#
#       pop     pop_dens    frg_pct       emp  tax_income
# 0    7344   632.558140  11.410675    3617.0       82162
# 1    7344   632.558140  11.410675    3617.0       82162
# 2    7344   632.558140  11.410675    3617.0       82162
# 3    7344   632.558140  11.410675    3617.0       82162
# 4  420217  4778.994655  32.458468  491193.0       85446

# %% [markdown]
# ### Count number of rows and columns in the data frame

# %%
# Dimension (rows, columns)
print('Dimension:', df.shape)

# Number of rows
print('Number of rows:', df.shape[0])

# Number of columns
print('Number of columns:', df.shape[1])
# Out:
# Dimension: (825, 14)
# Number of rows: 825
# Number of columns: 14

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Create additional variables from the apartment's descriptions

# %% [markdown]
# #### Create new binary (0/1) variable 'luxurious'

# %%
# Create a pattern which can be used to search the variable 'description_raw'
pattern = '(LOFT)|(SEESICHT)|(ATTIKA)|(LUXURIÖS)|(POOL)|(EXKLUSIV)'

# Create new variable 'luxurious' as binary dummy (0/1) variable
df['luxurious'] = df['description_raw'].str.contains(pat = pattern).astype(int)
print(df['luxurious'].sum())

# Show values
df[['description_raw','rooms','area','price','luxurious']]
# Out:
# 7
#                                        description_raw  rooms  area  price  \
# 0    «Grosse Galerie, Terrasse mit Pergola, Berg- u...    3.5   122   3180
# 1                       «Sehr grosse 4 Zimmer Wohnung»    4.0    87   1690
# 2               «Eigentumsstandard mit grossem Garten»    3.5    92   2350
# 3                          «CHARMANT HELL UND ZENTRAL»    3.5   130   2500
# 4              «Wunderschöne Wohnung im Enge-Quartier»    2.5    78   3760
# ..                                                 ...    ...   ...    ...
# 820                            «geräumig & weitläufig»    4.5   136   2610
# 821           «Wohnung an zentraler Lage zu vermieten»    4.5    85   1710
# 822              «Moderne Wohnung an idyllischer Lage»    3.5    94   2600
# 823                   «Erstbezug im Eigentumsstandard»    4.5   115   2580
# 824  «Wohnung an ruhiger Wohnlage mit Gartensitzplatz»    3.0    70   1640
#
#      luxurious
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 820          0
# 821          0
# 822          0
# 823          0
# 824          0
#
# [825 rows x 5 columns]

# %%
df[df['luxurious']==1]
# Out:
#      bfs_number  rooms  area  price  postalcode                address  \
# 174         261    4.5   171   7900        8053                    NaN
# 215         121    3.5   123   3350        8620                    NaN
# 518          53    4.5   124   3250        8180                    NaN
# 527          53    4.5   115   3250        8180                    NaN
# 537         111    2.0   110   2150        8344   Pfarrhausstrasse 18a
# 548          96    5.5    86   2500        8105                    NaN
# 711         224    4.5   130   2950        8422  Dättlikonerstrasse 16
#
#             town                                    description_raw  \
# 174       Zürich                «EXKLUSIV MÖBLIERT ODER UNMÖBLIERT»
# 215  Wetzikon ZH                      «LUXURIÖS, AN SCHÖNSTER LAGE»
# 518       Bülach     «EXKLUSIV UND HOCHWERTIG MIT IDEALER AUSSICHT»
# 527       Bülach  «EXKLUSIVE AUSSTATTUNG MIT GROSSARTIGER AUSSICHT»
# 537    Bäretswil                                «EXKLUSIVES WOHNEN»
# 548         Watt  «ZENTRAL, RUHIG, MIT EXKLUSIVER TERRASSE, GARTEN»
# 711      Pfungen     «GROSSE FANTASTISCHE TERRASSEN-ATTIKA-WOHNUNG»
#
#           bfs_name     pop     pop_dens    frg_pct       emp  tax_income  \
# 174         Zürich  420217  4778.994655  32.458468  491193.0       85446
# 215  Wetzikon (ZH)   24990  1486.615110  25.994398   14163.0       68951
# 518         Bülach   21372  1328.278434  28.032004   10973.0       78194
# 527         Bülach   21372  1328.278434  28.032004   10973.0       78194
# 537      Bäretswil    5053   227.715187  10.152385    1647.0       77877
# 548     Regensdorf   18540  1268.125855  35.571737   11126.0       73522
# 711        Pfungen    3900   781.563126  24.846154    1400.0       71575
#
#      luxurious
# 174          1
# 215          1
# 518          1
# 527          1
# 537          1
# 548          1
# 711          1

# %%
df.describe()
# Out:
#        bfs_number       rooms        area        price   postalcode  \
# count  825.000000  825.000000  825.000000   825.000000   825.000000
# mean   179.933333    3.313939   85.104242  2290.633939  8341.315152
# std     82.245926    1.108873   33.273780   940.825789   281.640466
# min      2.000000    1.000000   12.000000    16.000000  8001.000000
# 25%    112.000000    2.500000   65.000000  1700.000000  8057.000000
# 50%    199.000000    3.500000   82.000000  2080.000000  8307.000000
# 75%    261.000000    4.000000  100.000000  2600.000000  8603.000000
# max    298.000000    9.000000  300.000000  8900.000000  8955.000000
#
#                  pop     pop_dens     frg_pct            emp     tax_income  \
# count     825.000000   825.000000  825.000000     817.000000     825.000000
# mean   129338.147879  2175.274430   27.008149  140181.637699   82109.425455
# std    173285.858114  1656.633466    7.384090  207775.841297   15367.783878
# min       577.000000    82.310984    7.547170     129.000000   65147.000000
# 25%      8689.000000   826.991150   23.188001    2946.000000   71979.000000
# 50%     21372.000000  1662.597326   25.994398   14163.000000   80449.000000
# 75%    420217.000000  4778.994655   32.458468  491193.000000   85446.000000
# max    420217.000000  4778.994655   46.226483  491193.000000  193412.000000
#
#         luxurious
# count  825.000000
# mean     0.008485
# std      0.091777
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# #### Create new categorical variable based on apartment area

# %%
labels = ['0 - 49', '50 - 99', '100 - 500']
df["area_cat"] = pd.cut(df.area, bins=[0, 50, 100, 500], labels=labels)
df[['area', 'area_cat']].head(10)
# Out:
#    area   area_cat
# 0   122  100 - 500
# 1    87    50 - 99
# 2    92    50 - 99
# 3   130  100 - 500
# 4    78    50 - 99
# 5   195  100 - 500
# 6    59    50 - 99
# 7    75    50 - 99
# 8    58    50 - 99
# 9    52    50 - 99

# %% [markdown]
# #### Create new numeric variable 'price_per_m2'

# %%
# Create the new variable
df['price_per_m2'] = round(df['price'] / df['area'], 2)

# Show values
df[['description_raw','rooms','area', 'area_cat','price','luxurious', 'price_per_m2']]
# Out:
#                                        description_raw  rooms  area  \
# 0    «Grosse Galerie, Terrasse mit Pergola, Berg- u...    3.5   122
# 1                       «Sehr grosse 4 Zimmer Wohnung»    4.0    87
# 2               «Eigentumsstandard mit grossem Garten»    3.5    92
# 3                          «CHARMANT HELL UND ZENTRAL»    3.5   130
# 4              «Wunderschöne Wohnung im Enge-Quartier»    2.5    78
# ..                                                 ...    ...   ...
# 820                            «geräumig & weitläufig»    4.5   136
# 821           «Wohnung an zentraler Lage zu vermieten»    4.5    85
# 822              «Moderne Wohnung an idyllischer Lage»    3.5    94
# 823                   «Erstbezug im Eigentumsstandard»    4.5   115
# 824  «Wohnung an ruhiger Wohnlage mit Gartensitzplatz»    3.0    70
#
#       area_cat  price  luxurious  price_per_m2
# 0    100 - 500   3180          0         26.07
# 1      50 - 99   1690          0         19.43
# 2      50 - 99   2350          0         25.54
# 3    100 - 500   2500          0         19.23
# 4      50 - 99   3760          0         48.21
# ..         ...    ...        ...           ...
# 820  100 - 500   2610          0         19.19
# 821    50 - 99   1710          0         20.12
# 822    50 - 99   2600          0         27.66
# 823  100 - 500   2580          0         22.43
# 824    50 - 99   1640          0         23.43
#
# [825 rows x 7 columns]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Count, identify and remove missing values

# %%
# Count missing values
print('Count missing values per variable')
print(pd.isna(df).sum(), '\n')

# Identify rows with missing values
print('Identify rows with missing values')
print(df.loc[df.isna().any(axis=1)][['rooms', 'area', 'price', 'address', 'emp']], '\n')

# Drop rows where at least one element is missing.
df2 = df.dropna()
df2.head()
# Out:
# Count missing values per variable
# bfs_number          0
# rooms               0
# area                0
# price               0
# postalcode          0
# address            50
# town                0
# description_raw     0
# bfs_name            0
# pop                 0
# pop_dens            0
# frg_pct             0
# emp                 8
# tax_income          0
# luxurious           0
# area_cat            0
# price_per_m2        0
# dtype: int64
#
# Identify rows with missing values
#      rooms  area  price               address       emp
# 2      3.5    92   2350                   NaN    3617.0
# 3      3.5   130   2500                   NaN    3617.0
# 30     3.5   110   2880                   NaN  491193.0
# 31     5.0    80   2900                   NaN  491193.0
# 48     4.5   137     16                   NaN  491193.0
# 68     4.5   135   4490                   NaN  491193.0
# 72     3.5   105   1990                   NaN  491193.0
# 75     1.0    28   2699                   NaN  491193.0
# 79     2.5    60   2780                   NaN  491193.0
# 86     2.5    70   3300                   NaN  491193.0
# 98     3.5    96   4500                   NaN  491193.0
# 112    2.5    96   3688                   NaN  491193.0
# 126    2.5    68   3125                   NaN  491193.0
# 159    4.5   167     24                   NaN  491193.0
# 161    3.0    74   2369                   NaN  491193.0
# 174    4.5   171   7900                   NaN  491193.0
# 182    4.0    85   3840                   NaN  491193.0
# 215    3.5   123   3350                   NaN   14163.0
# 223    3.5   120   2400                   NaN   14163.0
# 239    4.5    99   2000                   NaN    4370.0
# 268    4.5   124   4460                   NaN    5859.0
# 362    3.5    75   1840                   NaN   73339.0
# 410    4.5   100   1880        Dorfstrasse 84       NaN
# 411    4.5    86   1680       Dorfstrasse 100       NaN
# 412    3.5    84   2490     Brunaustrasse 160       NaN
# 413    5.5   173   2530  Huebwiesenstrasse 20       NaN
# 414    4.0   102   2150                   NaN       NaN
# 415    2.5    82   1500                   NaN       NaN
# 437    3.5    85   2690                   NaN   18911.0
# 449    1.0    70   1490                   NaN    1536.0
# 452    1.0    28   1390                   NaN    1536.0
# 482    3.5    88   1870                   NaN    1104.0
# 484    4.0    90   2125                   NaN    1104.0
# 518    4.5   124   3250                   NaN   10973.0
# 527    4.5   115   3250                   NaN   10973.0
# 538    2.5   119   2150                   NaN    1647.0
# 539    4.5   130   2920                   NaN     150.0
# 540    4.5   127   2820                   NaN     150.0
# 548    5.5    86   2500                   NaN   11126.0
# 550    3.5    75   2032                   NaN   11126.0
# 594    3.5    79   2650      Säntisstrasse 6a       NaN
# 611    2.5    46   1390                   NaN    3460.0
# 613    3.5    55   1290                   NaN    3460.0
# 644    5.0   145   3720                   NaN    1836.0
# 679    2.5    78   2600                   NaN    4597.0
# 681    2.5    78   2600                   NaN    4597.0
# 682    4.0    96   2300                   NaN    2802.0
# 685    3.5   110   1950                   NaN     175.0
# 695    2.5   125   3125                   NaN    6277.0
# 697    1.0    18   1150                   NaN    1413.0
# 735    5.0   100   2300                   NaN   37403.0
# 775    3.0    60   1420                   NaN    1937.0
# 777    4.5   116   1690                   NaN    1937.0
# 785    1.0    20   1790                   NaN    1748.0
# 787    1.0    70   2350                   NaN    1748.0
# 815    2.0    48   1490     Uhwieserstrasse 3       NaN
#    bfs_number  rooms  area  price  postalcode               address  \
# 0         112    3.5   122   3180        8633  Sunnenbergstrasse 15
# 1         112    4.0    87   1690        8633   Blumenbergstrasse 7
# 4         261    2.5    78   3760        8002        Lavaterstr. 63
# 5         261    5.5   195   6900        8002           Parkring 59
# 6         261    2.5    59   2920        8044       Flobotstrasse 2
#
#          town                                    description_raw bfs_name  \
# 0  Wolfhausen  «Grosse Galerie, Terrasse mit Pergola, Berg- u...  Bubikon
# 1  Wolfhausen                     «Sehr grosse 4 Zimmer Wohnung»  Bubikon
# 4      Zürich            «Wunderschöne Wohnung im Enge-Quartier»   Zürich
# 5      Zürich  «Wohnanlage Im Parkring - Exklusive Wohnung zu...   Zürich
# 6      Zürich  «Erstvermietung am Zürichberg: Charmante 2.5-Z...   Zürich
#
#       pop     pop_dens    frg_pct       emp  tax_income  luxurious   area_cat  \
# 0    7344   632.558140  11.410675    3617.0       82162          0  100 - 500
# 1    7344   632.558140  11.410675    3617.0       82162          0    50 - 99
# 4  420217  4778.994655  32.458468  491193.0       85446          0    50 - 99
# 5  420217  4778.994655  32.458468  491193.0       85446          0  100 - 500
# 6  420217  4778.994655  32.458468  491193.0       85446          0    50 - 99
#
#    price_per_m2
# 0         26.07
# 1         19.43
# 4         48.21
# 5         35.38
# 6         49.49

# %%
median = df['emp'].median()
df['emp'].fillna(median, inplace=True)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")
imputer.fit(df[['rooms', 'area', 'price', 'pop', 'pop_dens', 'emp', 'tax_income']])

np.set_printoptions(suppress=True)
print(imputer.statistics_)
print('-----')
print(df[['rooms', 'area', 'price', 'pop', 'pop_dens', 'emp', 'tax_income']].median())
# Out:
# [    3.5           82.          2080.         21372.
#   1662.59732628 14163.         80449.        ]
# -----
# rooms             3.500000
# area             82.000000
# price          2080.000000
# pop           21372.000000
# pop_dens       1662.597326
# emp           14163.000000
# tax_income    80449.000000
# dtype: float64

# %% [markdown]
# ### Count, identify & remove duplicated values

# %%
# Count duplicated values in the whole data set
print('Sum of missing values:', df.duplicated().sum(), '\n')

# Identify duplicated values in 'rooms', 'area', 'price'
print('Duplicated values')
print(df.loc[df.duplicated(keep = 'last')])

# Drop the rows with duplicated values
df3 = df2.drop_duplicates()
# Out:
# Sum of missing values: 7
#
# Duplicated values
#      bfs_number  rooms  area  price  postalcode                 address  \
# 17          261    1.5    32   2100        8049           Am Wasser 161
# 53          261    2.5    60   2500        8048            Herrligweg 9
# 84          261    3.5    74   4200        8004     Badenerstrasse  250
# 123         261    2.5    42   3000        8049           Am Wasser 161
# 166         261    1.5    22   1750        8049           Am Wasser 161
# 502          66    2.5    46   1630        8152  Boulevard Lilienthal 5
# 679          52    2.5    78   2600        8303                     NaN
#
#             town                                  description_raw  \
# 17        Zürich         «MÖBLIERTE WOHNUNG DIREKT AN DER LIMMAT»
# 53        Zürich            «Wohnung im Grünen und doch zentral!»
# 84        Zürich            «Neu - Luxuriös - Am Puls von Zürich»
# 123       Zürich       «Traumhafte Wohnoase direkt an der Limmat»
# 166       Zürich                              «WOW AN DER LIMMAT»
# 502      Opfikon  «Gemütliche Wohnung im Glattpark zu vermieten!»
# 679  Bassersdorf        «MODERN UND CHARMANT MIT GARTENSITZPLATZ»
#
#         bfs_name     pop     pop_dens    frg_pct       emp  tax_income  \
# 17        Zürich  420217  4778.994655  32.458468  491193.0       85446
# 53        Zürich  420217  4778.994655  32.458468  491193.0       85446
# 84        Zürich  420217  4778.994655  32.458468  491193.0       85446
# 123       Zürich  420217  4778.994655  32.458468  491193.0       85446
# 166       Zürich  420217  4778.994655  32.458468  491193.0       85446
# 502      Opfikon   21014  3759.212880  44.912915   19226.0       71979
# 679  Bassersdorf   11824  1309.413068  24.949256    4597.0       79477
#
#      luxurious area_cat  price_per_m2
# 17           0   0 - 49         65.62
# 53           0  50 - 99         41.67
# 84           0  50 - 99         56.76
# 123          0   0 - 49         71.43
# 166          0   0 - 49         79.55
# 502          0   0 - 49         35.43
# 679          0  50 - 99         33.33

# %% [markdown]
# #### Save data to file

# %%
df3.columns
# Out:
# Index(['bfs_number', 'rooms', 'area', 'price', 'postalcode', 'address', 'town',
#        'description_raw', 'bfs_name', 'pop', 'pop_dens', 'frg_pct', 'emp',
#        'tax_income', 'luxurious', 'area_cat', 'price_per_m2'],
#       dtype='object')

# %%
df3.to_csv('apartments_data_enriched.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)
