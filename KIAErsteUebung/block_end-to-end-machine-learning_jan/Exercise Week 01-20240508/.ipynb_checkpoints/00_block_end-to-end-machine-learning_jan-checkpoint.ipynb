# %% [markdown]
# # The link to your application:
# >  Please provide the link to your application.
#
# Application: https://leafy-florentine-43e752.netlify.app/appartment
#
#
# Backend: https://reiflja2.pythonanywhere.com
# <br>
# Backend Example: https://reiflja2.pythonanywhere.com/api/prediction/apartment?bfs_number=261&area=50&rooms=2

# %% [markdown]
# # Iterative Process:
# >  You should employ at least two iterations of model training/selection, incorporating additional data and utilizing different features, among other modifications. For each iteration, articulate the objectives and the alterations made. Describe the following for each iteration:
#
# ## Iteration 1
#
# ### Data Preprocessing:
# >  Bullet-point list detailing all data preprocessing steps you used
# -  Extracted room, area, and price from "rooms_area_price_raw".
# -  Matched postal codes with municipality names for additional data.
# -  Converted numeric variables to suitable data types as necessary.
# -  Extracted and stored essential dataset information.
# -  Incorporated municipality data based on postal codes.
# -  Addressed missing and duplicate values in the dataset.
# -  Transformed categorical variables into numerical representations.
# -  Removed missing values from the dataset to ensure data completeness.
# -  Standardized numerical variables to have zero mean and unit variance.
# -  Encoded categorical variables using one-hot encoding to represent them numerically.
# -  Split the dataset into training and testing sets for model evaluation.
#
# ### Models:
# >  Specify at least two models used, along with their respective hyperparameters (e.g., Linear Regression, Random Forest, etc.).
# Linear regression
#
# Iteration 1: Linear Regression
#
# ### Performance Metrics:
# >  Provide the training/validation/test scores of the models used.
#
# There are a lot of diffrent performance metrics. In order to keep this Jupyter notebook short, only a few are listed here. The remaining performance metrics can be found in the Jupyter Notebook 3_linear_regression_sklearn.ipynb.
#
# train mean_squared_error 214364.68329001506<br>
# train root_mean_squared_error 462.9953383026821
#
# test mean_squared_error  252143.99232557917<br>
# test root_mean_squared_error  502.1394152280611
#
#
# ## Iteration 2
#
# ### Data Preprocessing:
# >  Bullet-point list detailing all data preprocessing steps you used
#
# The data preprocessing is the same as in Interation 1
# -  Extracted room, area, and price from "rooms_area_price_raw".
# -  Matched postal codes with municipality names for additional data.
# -  Converted numeric variables to suitable data types as necessary.
# -  Extracted and stored essential dataset information.
# -  Incorporated municipality data based on postal codes.
# -  Addressed missing and duplicate values in the dataset.
# -  Transformed categorical variables into numerical representations.
# -  Removed missing values from the dataset to ensure data completeness.
# -  Standardized numerical variables to have zero mean and unit variance.
# -  Encoded categorical variables using one-hot encoding to represent them numerically.
# -  Split the dataset into training and testing sets for model evaluation.
#
# ### Models:
# >  Specify at least two models used, along with their respective hyperparameters (e.g., Linear Regression, Random Forest, etc.).
#
# Iteration 2: Random Forest
#
# ### Performance Metrics:
# >  Provide the training/validation/test scores of the models used.
#
# There are a lot of diffrent performance metrics. In order to keep this Jupyter notebook short, only a few are listed here. The remaining performance metrics can be found in the Jupyter Notebook 4_random_forest_sklearn.ipynb.
#
# train mean_squared_error 91238.61398540842<br>
# train root_mean_squared_error 302.0573024864792
#
# test mean_squared_error  228794.5031386942<br>
# test root_mean_squared_error  478.32468380661084
